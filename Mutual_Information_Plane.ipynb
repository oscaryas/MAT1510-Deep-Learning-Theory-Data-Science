# %% [markdown]
# <a href="https://colab.research.google.com/github/oscaryas/MAT1510/blob/main/Mutual_Information_Plane.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Goal**<br>
# The goal of this exercise is to generate the information plane studied in class for a multilayer perceptron trained on the MNIST dataset (projected to 12 dimensions using PCA).
#
# *Before you start, make sure to change the runtime type to include a GPU!*
#
# <br>
#
# **Task (adding two lines of code)**<br>
# Implement the calculation of the empirical mutual informations $\hat{I} (X;H)$ and $\hat{I} (Y;H)$.
#
# Hint: use the python functions sum and math.log2
#
# <br>
#
# **Submission**<br>
# *   Download your code by clicking File -> Download .ipynb
# *   Submit your downloaded code on Quercus

# %%
import math
import torch
import numpy as np
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import torch.nn.functional as F
import torchvision.models as models

from collections import Counter
from sklearn.decomposition import PCA
from torch.utils.data import TensorDataset
from torchvision import datasets, transforms

# %%
# hyperparameters
device        = 'cuda'
lr            = 7e-2
epochs        = 10
milestones    = [epochs//2]
gamma         = 0.5
batch_size    = 512
momentum      = 0
weight_decay  = 0
n_bins        = 10

# %%
# deep network
class Model(nn.Module):
    def __init__(self):
        super(Model, self).__init__()
        self.fc1 = nn.Linear(12, 10)
        self.fc2 = nn.Linear(10, 7)
        self.fc3 = nn.Linear(7, 5)
        self.fc4 = nn.Linear(5, 4)
        self.fc5 = nn.Linear(4, 3)
        self.fc6 = nn.Linear(3, 2)

    def forward(self, x):
        h1 = torch.tanh(self.fc1(x))
        h2 = torch.tanh(self.fc2(h1))
        h3 = torch.tanh(self.fc3(h2))
        h4 = torch.tanh(self.fc4(h3))
        h5 = torch.tanh(self.fc5(h4))
        h6 = F.log_softmax(self.fc6(h5), dim=1)
        return h1, h2, h3, h4, h5, h6

model = Model().to(device)

def process_dataset(dataset):
    # keep only images of two digits
    digit1 = 0
    digit2 = 2

    indices = (dataset.targets == digit1) | (dataset.targets == digit2)
    dataset.data, dataset.targets = dataset.data[indices], dataset.targets[indices]

    dataset.targets[dataset.targets == digit1] = 0
    dataset.targets[dataset.targets == digit2] = 1

    dataset = TensorDataset(dataset.data.reshape(-1, 28*28), dataset.targets)

    return dataset

transform = transforms.ToTensor()
train_dataset = process_dataset(datasets.MNIST('../data', download=True, train=True, transform=transform))
test_dataset = process_dataset(datasets.MNIST('../data', download=True, train=False, transform=transform))

# use PCA to reduce to 12 dimensions
pca = PCA(n_components=12)
pca.fit(train_dataset.tensors[0])
train_dataset.tensors = (torch.from_numpy(pca.transform(train_dataset.tensors[0])).float(), train_dataset.tensors[1])
test_dataset.tensors = (torch.from_numpy(pca.transform(test_dataset.tensors[0])).float(), test_dataset.tensors[1])

# dataset loaders
train_loader = torch.utils.data.DataLoader(
    train_dataset, batch_size=batch_size, shuffle=True, drop_last=True)

train_loader_full = torch.utils.data.DataLoader(
    train_dataset, batch_size=len(train_loader.dataset), shuffle=False, drop_last=False)

test_loader = torch.utils.data.DataLoader(
    test_dataset, batch_size=batch_size, shuffle=False, drop_last=False)

# loss function
loss_function = nn.NLLLoss()

# optimizer
optimizer = optim.SGD(model.parameters(),
                      lr=lr,
                      momentum=momentum,
                      weight_decay=weight_decay)
scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=milestones, gamma=gamma)
# Out:
# 100%|██████████| 9.91M/9.91M [00:01<00:00, 5.53MB/s]
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 130kB/s]
# 100%|██████████| 1.65M/1.65M [00:01<00:00, 1.23MB/s]
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 10.9MB/s]

# %%
train_accuracy = []
test_accuracy = []

# mutual informations for every epoch and every layer
layers = len(list(model.children()))
MI_XH = torch.zeros(epochs, layers)
MI_YH = torch.zeros(epochs, layers)

# iterate over epochs
for epoch in range(epochs):
    # run model on full train dataset
    for images, labels in train_loader_full:
        images, labels = images.to(device), labels.to(device)

    h_list = model(images)

    # calculate mutual information
    for layer, h in enumerate(h_list):
        # discretize images and representations
        bins = np.linspace(0, 1, n_bins+1)
        x_ = np.digitize(images.cpu(), bins)
        if layer == layers-1:
            h = torch.exp(h)
            bins = np.linspace(0, 1, n_bins+1)
        else:
            bins = np.linspace(-1, 1, n_bins+1)
        h_ = np.digitize(h.cpu().detach().numpy(), bins)
        y_ = labels.cpu()

        # calculate discrete probabilities
        p_X = Counter()
        p_Y = Counter()
        p_H = Counter()
        p_XH = Counter()
        p_YH = Counter()

        for x_i, h_i, y_i in zip(x_, h_, y_):
            def totuple(a):
                try:
                    return tuple(totuple(i) for i in a)
                except:
                    return a.item()

            unit = 1./len(images)

            p_X[totuple(x_i)]                   += unit
            p_Y[totuple(y_i)]                   += unit
            p_H[totuple(h_i)]                   += unit
            p_XH[(totuple(x_i), totuple(h_i))]  += unit
            p_YH[(totuple(y_i), totuple(h_i))]  += unit

        # ADD CODE HERE
        eps = 1e-12  # numerical stability

        # For MI(X;H)
        keys_xh = list(p_XH.keys())
        p_xh_vals = torch.tensor([p_XH[k] for k in keys_xh], dtype=torch.float32)
        p_x_vals  = torch.tensor([p_X[k[0]] for k in keys_xh], dtype=torch.float32)
        p_h_vals  = torch.tensor([p_H[k[1]] for k in keys_xh], dtype=torch.float32)

        # I(X;H) = sum p(x,h) log2 [ p(x,h) / (p(x)p(h)) ]
        ratio_xh = p_xh_vals / (p_x_vals * p_h_vals + eps)
        mi_xh = torch.sum(p_xh_vals * torch.log2(ratio_xh + eps))

        # For MI(Y;H)
        keys_yh = list(p_YH.keys())
        p_yh_vals = torch.tensor([p_YH[k] for k in keys_yh], dtype=torch.float32)
        p_y_vals  = torch.tensor([p_Y[k[0]] for k in keys_yh], dtype=torch.float32)
        p_h_vals2 = torch.tensor([p_H[k[1]] for k in keys_yh], dtype=torch.float32)

        ratio_yh = p_yh_vals / (p_y_vals * p_h_vals2 + eps)
        mi_yh = torch.sum(p_yh_vals * torch.log2(ratio_yh + eps))

        # store in MI matrices
        MI_XH[epoch, layer] = mi_xh
        MI_YH[epoch, layer] = mi_yh


    # train phase
    model.train()
    accuracy = 0
    N = 0

    # iterate over train data
    for batch_idx, (images, labels) in enumerate(train_loader, start=1):
        images, labels = images.to(device), labels.to(device)

        # forward pass
        h1, h2, h3, h4, h5, h6 = model(images)
        loss = loss_function(h6, labels)

        # backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # check if predicted labels are equal to true labels
        predicted_labels = torch.argmax(h6,dim=1)
        accuracy += torch.sum((predicted_labels==labels).float()).item()
        N += images.shape[0]

        print('Train\t\tEpoch: {} \t'
              'Batch {}/{} ({:.0f}%) \t'
              'Batch Loss: {:.6f} \t'
              'Batch Accuracy: {:.6f}'.format(
                  epoch+1,
                  batch_idx,
                  len(train_loader),
                  100. * batch_idx / len(train_loader),
                  loss.item(),
                  100. * accuracy/N))

    train_accuracy.append(100. * accuracy/N)

    scheduler.step()

    # test phase
    model.eval()
    accuracy = 0
    N = 0

    # iterate over test data
    for batch_idx, (images, labels) in enumerate(test_loader, start=1):
        images, labels = images.to(device), labels.to(device)

        # forward pass
        h1, h2, h3, h4, h5, h6 = model(images)

        # check if predicted labels are equal to true labels
        predicted_labels = torch.argmax(h6,dim=1)
        accuracy += torch.sum((predicted_labels==labels).float()).item()
        N += images.shape[0]
    test_accuracy.append(100. * accuracy/N)
    print(test_accuracy[-1])

# plot results
plt.figure()
plt.title('Accuracy Versus Epoch')
plt.plot(range(1, epochs+1), train_accuracy, label='Train')
plt.plot(range(1, epochs+1), test_accuracy, label='Test')
plt.legend()

plt.figure()
fig, ax = plt.subplots(figsize=(8, 8))
ax.set_xlabel('MI_X,H')
ax.set_ylabel('MI_Y,H')
title = ax.set_title('Information Plane')
cmap = plt.get_cmap('gnuplot', epochs)
colors = [cmap(i) for i in np.linspace(0, 1, epochs)]
ax.plot(MI_XH, MI_YH, '-', color='gray')
for layer in range(layers):
    im = ax.scatter(MI_XH[:,layer], MI_YH[:,layer], c=colors)
# Out:
# Train		Epoch: 1 	Batch 1/23 (4%) 	Batch Loss: 0.679206 	Batch Accuracy: 79.687500
# Train		Epoch: 1 	Batch 2/23 (9%) 	Batch Loss: 0.679356 	Batch Accuracy: 78.515625
# Train		Epoch: 1 	Batch 3/23 (13%) 	Batch Loss: 0.679235 	Batch Accuracy: 78.841146
# Train		Epoch: 1 	Batch 4/23 (17%) 	Batch Loss: 0.679258 	Batch Accuracy: 78.027344
# Train		Epoch: 1 	Batch 5/23 (22%) 	Batch Loss: 0.678952 	Batch Accuracy: 77.968750
# Train		Epoch: 1 	Batch 6/23 (26%) 	Batch Loss: 0.678804 	Batch Accuracy: 78.190104
# Train		Epoch: 1 	Batch 7/23 (30%) 	Batch Loss: 0.676910 	Batch Accuracy: 78.431920
# Train		Epoch: 1 	Batch 8/23 (35%) 	Batch Loss: 0.679635 	Batch Accuracy: 78.149414
# Train		Epoch: 1 	Batch 9/23 (39%) 	Batch Loss: 0.676872 	Batch Accuracy: 78.450521
# Train		Epoch: 1 	Batch 10/23 (43%) 	Batch Loss: 0.677911 	Batch Accuracy: 78.359375
# Train		Epoch: 1 	Batch 11/23 (48%) 	Batch Loss: 0.678151 	Batch Accuracy: 78.480114
# Train		Epoch: 1 	Batch 12/23 (52%) 	Batch Loss: 0.677271 	Batch Accuracy: 78.515625
# Train		Epoch: 1 	Batch 13/23 (57%) 	Batch Loss: 0.676371 	Batch Accuracy: 78.605769
# Train		Epoch: 1 	Batch 14/23 (61%) 	Batch Loss: 0.677221 	Batch Accuracy: 78.445871
# Train		Epoch: 1 	Batch 15/23 (65%) 	Batch Loss: 0.677180 	Batch Accuracy: 78.437500
# Train		Epoch: 1 	Batch 16/23 (70%) 	Batch Loss: 0.675434 	Batch Accuracy: 78.710938
# Train		Epoch: 1 	Batch 17/23 (74%) 	Batch Loss: 0.675683 	Batch Accuracy: 78.802849
# Train		Epoch: 1 	Batch 18/23 (78%) 	Batch Loss: 0.675555 	Batch Accuracy: 78.830295
# Train		Epoch: 1 	Batch 19/23 (83%) 	Batch Loss: 0.676220 	Batch Accuracy: 78.690378
# Train		Epoch: 1 	Batch 20/23 (87%) 	Batch Loss: 0.674710 	Batch Accuracy: 78.662109
# Train		Epoch: 1 	Batch 21/23 (91%) 	Batch Loss: 0.674446 	Batch Accuracy: 78.692336
# Train		Epoch: 1 	Batch 22/23 (96%) 	Batch Loss: 0.676686 	Batch Accuracy: 78.622159
# Train		Epoch: 1 	Batch 23/23 (100%) 	Batch Loss: 0.674124 	Batch Accuracy: 78.753397
# 77.78330019880715
# Train		Epoch: 2 	Batch 1/23 (4%) 	Batch Loss: 0.674746 	Batch Accuracy: 78.515625
# Train		Epoch: 2 	Batch 2/23 (9%) 	Batch Loss: 0.675010 	Batch Accuracy: 78.808594
# Train		Epoch: 2 	Batch 3/23 (13%) 	Batch Loss: 0.672403 	Batch Accuracy: 79.557292
# Train		Epoch: 2 	Batch 4/23 (17%) 	Batch Loss: 0.674913 	Batch Accuracy: 78.955078
# Train		Epoch: 2 	Batch 5/23 (22%) 	Batch Loss: 0.671590 	Batch Accuracy: 79.843750
# Train		Epoch: 2 	Batch 6/23 (26%) 	Batch Loss: 0.671032 	Batch Accuracy: 80.208333
# Train		Epoch: 2 	Batch 7/23 (30%) 	Batch Loss: 0.671370 	Batch Accuracy: 80.747768
# Train		Epoch: 2 	Batch 8/23 (35%) 	Batch Loss: 0.672518 	Batch Accuracy: 80.590820
# Train		Epoch: 2 	Batch 9/23 (39%) 	Batch Loss: 0.670949 	Batch Accuracy: 80.620660
# Train		Epoch: 2 	Batch 10/23 (43%) 	Batch Loss: 0.671990 	Batch Accuracy: 80.488281
# Train		Epoch: 2 	Batch 11/23 (48%) 	Batch Loss: 0.671655 	Batch Accuracy: 80.415483
# Train		Epoch: 2 	Batch 12/23 (52%) 	Batch Loss: 0.669772 	Batch Accuracy: 80.615234
# Train		Epoch: 2 	Batch 13/23 (57%) 	Batch Loss: 0.671180 	Batch Accuracy: 80.483774
# Train		Epoch: 2 	Batch 14/23 (61%) 	Batch Loss: 0.669388 	Batch Accuracy: 80.566406
# Train		Epoch: 2 	Batch 15/23 (65%) 	Batch Loss: 0.668954 	Batch Accuracy: 80.598958
# Train		Epoch: 2 	Batch 16/23 (70%) 	Batch Loss: 0.669426 	Batch Accuracy: 80.749512
# Train		Epoch: 2 	Batch 17/23 (74%) 	Batch Loss: 0.667574 	Batch Accuracy: 80.859375
# Train		Epoch: 2 	Batch 18/23 (78%) 	Batch Loss: 0.667668 	Batch Accuracy: 80.913628
# Train		Epoch: 2 	Batch 19/23 (83%) 	Batch Loss: 0.668029 	Batch Accuracy: 80.972451
# Train		Epoch: 2 	Batch 20/23 (87%) 	Batch Loss: 0.666109 	Batch Accuracy: 81.044922
# Train		Epoch: 2 	Batch 21/23 (91%) 	Batch Loss: 0.668692 	Batch Accuracy: 81.129092
# Train		Epoch: 2 	Batch 22/23 (96%) 	Batch Loss: 0.664476 	Batch Accuracy: 81.241122
# Train		Epoch: 2 	Batch 23/23 (100%) 	Batch Loss: 0.664360 	Batch Accuracy: 81.334918
# 79.72166998011929
# Train		Epoch: 3 	Batch 1/23 (4%) 	Batch Loss: 0.664150 	Batch Accuracy: 82.617188
# Train		Epoch: 3 	Batch 2/23 (9%) 	Batch Loss: 0.663323 	Batch Accuracy: 82.421875
# Train		Epoch: 3 	Batch 3/23 (13%) 	Batch Loss: 0.662826 	Batch Accuracy: 82.421875
# Train		Epoch: 3 	Batch 4/23 (17%) 	Batch Loss: 0.663233 	Batch Accuracy: 82.812500
# Train		Epoch: 3 	Batch 5/23 (22%) 	Batch Loss: 0.662704 	Batch Accuracy: 82.812500
# Train		Epoch: 3 	Batch 6/23 (26%) 	Batch Loss: 0.662467 	Batch Accuracy: 82.617188
# Train		Epoch: 3 	Batch 7/23 (30%) 	Batch Loss: 0.661903 	Batch Accuracy: 82.617188
# Train		Epoch: 3 	Batch 8/23 (35%) 	Batch Loss: 0.660375 	Batch Accuracy: 82.836914
# Train		Epoch: 3 	Batch 9/23 (39%) 	Batch Loss: 0.660513 	Batch Accuracy: 82.921007
# Train		Epoch: 3 	Batch 10/23 (43%) 	Batch Loss: 0.660240 	Batch Accuracy: 82.988281
# Train		Epoch: 3 	Batch 11/23 (48%) 	Batch Loss: 0.657867 	Batch Accuracy: 83.078835
# Train		Epoch: 3 	Batch 12/23 (52%) 	Batch Loss: 0.658130 	Batch Accuracy: 83.170573
# Train		Epoch: 3 	Batch 13/23 (57%) 	Batch Loss: 0.656250 	Batch Accuracy: 83.188101
# Train		Epoch: 3 	Batch 14/23 (61%) 	Batch Loss: 0.658065 	Batch Accuracy: 83.091518
# Train		Epoch: 3 	Batch 15/23 (65%) 	Batch Loss: 0.657140 	Batch Accuracy: 82.981771
# Train		Epoch: 3 	Batch 16/23 (70%) 	Batch Loss: 0.658332 	Batch Accuracy: 82.849121
# Train		Epoch: 3 	Batch 17/23 (74%) 	Batch Loss: 0.654121 	Batch Accuracy: 82.915901
# Train		Epoch: 3 	Batch 18/23 (78%) 	Batch Loss: 0.655126 	Batch Accuracy: 82.986111
# Train		Epoch: 3 	Batch 19/23 (83%) 	Batch Loss: 0.653354 	Batch Accuracy: 83.007812
# Train		Epoch: 3 	Batch 20/23 (87%) 	Batch Loss: 0.654791 	Batch Accuracy: 83.027344
# Train		Epoch: 3 	Batch 21/23 (91%) 	Batch Loss: 0.650190 	Batch Accuracy: 83.147321
# Train		Epoch: 3 	Batch 22/23 (96%) 	Batch Loss: 0.650373 	Batch Accuracy: 83.212003
# Train		Epoch: 3 	Batch 23/23 (100%) 	Batch Loss: 0.649621 	Batch Accuracy: 83.271060
# 82.95228628230616
# Train		Epoch: 4 	Batch 1/23 (4%) 	Batch Loss: 0.648823 	Batch Accuracy: 84.570312
# Train		Epoch: 4 	Batch 2/23 (9%) 	Batch Loss: 0.647752 	Batch Accuracy: 84.765625
# Train		Epoch: 4 	Batch 3/23 (13%) 	Batch Loss: 0.645705 	Batch Accuracy: 85.026042
# Train		Epoch: 4 	Batch 4/23 (17%) 	Batch Loss: 0.646215 	Batch Accuracy: 84.521484
# Train		Epoch: 4 	Batch 5/23 (22%) 	Batch Loss: 0.644961 	Batch Accuracy: 84.570312
# Train		Epoch: 4 	Batch 6/23 (26%) 	Batch Loss: 0.641320 	Batch Accuracy: 85.221354
# Train		Epoch: 4 	Batch 7/23 (30%) 	Batch Loss: 0.641117 	Batch Accuracy: 85.463170
# Train		Epoch: 4 	Batch 8/23 (35%) 	Batch Loss: 0.642761 	Batch Accuracy: 85.278320
# Train		Epoch: 4 	Batch 9/23 (39%) 	Batch Loss: 0.637426 	Batch Accuracy: 85.199653
# Train		Epoch: 4 	Batch 10/23 (43%) 	Batch Loss: 0.634773 	Batch Accuracy: 85.410156
# Train		Epoch: 4 	Batch 11/23 (48%) 	Batch Loss: 0.636979 	Batch Accuracy: 85.404830
# Train		Epoch: 4 	Batch 12/23 (52%) 	Batch Loss: 0.638949 	Batch Accuracy: 85.351562
# Train		Epoch: 4 	Batch 13/23 (57%) 	Batch Loss: 0.632629 	Batch Accuracy: 85.471755
# Train		Epoch: 4 	Batch 14/23 (61%) 	Batch Loss: 0.626744 	Batch Accuracy: 85.797991
# Train		Epoch: 4 	Batch 15/23 (65%) 	Batch Loss: 0.630417 	Batch Accuracy: 85.833333
# Train		Epoch: 4 	Batch 16/23 (70%) 	Batch Loss: 0.630846 	Batch Accuracy: 85.827637
# Train		Epoch: 4 	Batch 17/23 (74%) 	Batch Loss: 0.631009 	Batch Accuracy: 85.811121
# Train		Epoch: 4 	Batch 18/23 (78%) 	Batch Loss: 0.626315 	Batch Accuracy: 85.894097
# Train		Epoch: 4 	Batch 19/23 (83%) 	Batch Loss: 0.624293 	Batch Accuracy: 85.947780
# Train		Epoch: 4 	Batch 20/23 (87%) 	Batch Loss: 0.623468 	Batch Accuracy: 86.015625
# Train		Epoch: 4 	Batch 21/23 (91%) 	Batch Loss: 0.627601 	Batch Accuracy: 85.890997
# Train		Epoch: 4 	Batch 22/23 (96%) 	Batch Loss: 0.621935 	Batch Accuracy: 85.919744
# Train		Epoch: 4 	Batch 23/23 (100%) 	Batch Loss: 0.619720 	Batch Accuracy: 85.962976
# 87.67395626242545
# Train		Epoch: 5 	Batch 1/23 (4%) 	Batch Loss: 0.609797 	Batch Accuracy: 90.429688
# Train		Epoch: 5 	Batch 2/23 (9%) 	Batch Loss: 0.611045 	Batch Accuracy: 90.332031
# Train		Epoch: 5 	Batch 3/23 (13%) 	Batch Loss: 0.616940 	Batch Accuracy: 88.802083
# Train		Epoch: 5 	Batch 4/23 (17%) 	Batch Loss: 0.612651 	Batch Accuracy: 88.574219
# Train		Epoch: 5 	Batch 5/23 (22%) 	Batch Loss: 0.608846 	Batch Accuracy: 88.398438
# Train		Epoch: 5 	Batch 6/23 (26%) 	Batch Loss: 0.607171 	Batch Accuracy: 88.476562
# Train		Epoch: 5 	Batch 7/23 (30%) 	Batch Loss: 0.610921 	Batch Accuracy: 87.890625
# Train		Epoch: 5 	Batch 8/23 (35%) 	Batch Loss: 0.598904 	Batch Accuracy: 88.085938
# Train		Epoch: 5 	Batch 9/23 (39%) 	Batch Loss: 0.599804 	Batch Accuracy: 88.194444
# Train		Epoch: 5 	Batch 10/23 (43%) 	Batch Loss: 0.598191 	Batch Accuracy: 88.164062
# Train		Epoch: 5 	Batch 11/23 (48%) 	Batch Loss: 0.592622 	Batch Accuracy: 88.210227
# Train		Epoch: 5 	Batch 12/23 (52%) 	Batch Loss: 0.594289 	Batch Accuracy: 88.232422
# Train		Epoch: 5 	Batch 13/23 (57%) 	Batch Loss: 0.589494 	Batch Accuracy: 88.341346
# Train		Epoch: 5 	Batch 14/23 (61%) 	Batch Loss: 0.588290 	Batch Accuracy: 88.337054
# Train		Epoch: 5 	Batch 15/23 (65%) 	Batch Loss: 0.585677 	Batch Accuracy: 88.411458
# Train		Epoch: 5 	Batch 16/23 (70%) 	Batch Loss: 0.578892 	Batch Accuracy: 88.488770
# Train		Epoch: 5 	Batch 17/23 (74%) 	Batch Loss: 0.571006 	Batch Accuracy: 88.763787
# Train		Epoch: 5 	Batch 18/23 (78%) 	Batch Loss: 0.569966 	Batch Accuracy: 88.943142
# Train		Epoch: 5 	Batch 19/23 (83%) 	Batch Loss: 0.567606 	Batch Accuracy: 89.124178
# Train		Epoch: 5 	Batch 20/23 (87%) 	Batch Loss: 0.563890 	Batch Accuracy: 89.208984
# Train		Epoch: 5 	Batch 21/23 (91%) 	Batch Loss: 0.563659 	Batch Accuracy: 89.285714
# Train		Epoch: 5 	Batch 22/23 (96%) 	Batch Loss: 0.558107 	Batch Accuracy: 89.355469
# Train		Epoch: 5 	Batch 23/23 (100%) 	Batch Loss: 0.552030 	Batch Accuracy: 89.470109
# 92.04771371769384
# Train		Epoch: 6 	Batch 1/23 (4%) 	Batch Loss: 0.553744 	Batch Accuracy: 90.234375
# Train		Epoch: 6 	Batch 2/23 (9%) 	Batch Loss: 0.545312 	Batch Accuracy: 90.820312
# Train		Epoch: 6 	Batch 3/23 (13%) 	Batch Loss: 0.536640 	Batch Accuracy: 91.406250
# Train		Epoch: 6 	Batch 4/23 (17%) 	Batch Loss: 0.533793 	Batch Accuracy: 91.796875
# Train		Epoch: 6 	Batch 5/23 (22%) 	Batch Loss: 0.530504 	Batch Accuracy: 91.914062
# Train		Epoch: 6 	Batch 6/23 (26%) 	Batch Loss: 0.531829 	Batch Accuracy: 91.796875
# Train		Epoch: 6 	Batch 7/23 (30%) 	Batch Loss: 0.523407 	Batch Accuracy: 91.936384
# Train		Epoch: 6 	Batch 8/23 (35%) 	Batch Loss: 0.520242 	Batch Accuracy: 92.016602
# Train		Epoch: 6 	Batch 9/23 (39%) 	Batch Loss: 0.523251 	Batch Accuracy: 91.905382
# Train		Epoch: 6 	Batch 10/23 (43%) 	Batch Loss: 0.514259 	Batch Accuracy: 91.972656
# Train		Epoch: 6 	Batch 11/23 (48%) 	Batch Loss: 0.509404 	Batch Accuracy: 91.885653
# Train		Epoch: 6 	Batch 12/23 (52%) 	Batch Loss: 0.498155 	Batch Accuracy: 91.992188
# Train		Epoch: 6 	Batch 13/23 (57%) 	Batch Loss: 0.495309 	Batch Accuracy: 92.007212
# Train		Epoch: 6 	Batch 14/23 (61%) 	Batch Loss: 0.490879 	Batch Accuracy: 92.061942
# Train		Epoch: 6 	Batch 15/23 (65%) 	Batch Loss: 0.490353 	Batch Accuracy: 92.070312
# Train		Epoch: 6 	Batch 16/23 (70%) 	Batch Loss: 0.484880 	Batch Accuracy: 92.077637
# Train		Epoch: 6 	Batch 17/23 (74%) 	Batch Loss: 0.477512 	Batch Accuracy: 92.084099
# Train		Epoch: 6 	Batch 18/23 (78%) 	Batch Loss: 0.473559 	Batch Accuracy: 92.122396
# Train		Epoch: 6 	Batch 19/23 (83%) 	Batch Loss: 0.467380 	Batch Accuracy: 92.166941
# Train		Epoch: 6 	Batch 20/23 (87%) 	Batch Loss: 0.457051 	Batch Accuracy: 92.167969
# Train		Epoch: 6 	Batch 21/23 (91%) 	Batch Loss: 0.456345 	Batch Accuracy: 92.234003
# Train		Epoch: 6 	Batch 22/23 (96%) 	Batch Loss: 0.443970 	Batch Accuracy: 92.294034
# Train		Epoch: 6 	Batch 23/23 (100%) 	Batch Loss: 0.446320 	Batch Accuracy: 92.323370
# 94.23459244532803
# Train		Epoch: 7 	Batch 1/23 (4%) 	Batch Loss: 0.445285 	Batch Accuracy: 91.992188
# Train		Epoch: 7 	Batch 2/23 (9%) 	Batch Loss: 0.427441 	Batch Accuracy: 92.480469
# Train		Epoch: 7 	Batch 3/23 (13%) 	Batch Loss: 0.423264 	Batch Accuracy: 92.968750
# Train		Epoch: 7 	Batch 4/23 (17%) 	Batch Loss: 0.420758 	Batch Accuracy: 93.164062
# Train		Epoch: 7 	Batch 5/23 (22%) 	Batch Loss: 0.415881 	Batch Accuracy: 93.281250
# Train		Epoch: 7 	Batch 6/23 (26%) 	Batch Loss: 0.417864 	Batch Accuracy: 93.131510
# Train		Epoch: 7 	Batch 7/23 (30%) 	Batch Loss: 0.407062 	Batch Accuracy: 93.136161
# Train		Epoch: 7 	Batch 8/23 (35%) 	Batch Loss: 0.405852 	Batch Accuracy: 93.115234
# Train		Epoch: 7 	Batch 9/23 (39%) 	Batch Loss: 0.383946 	Batch Accuracy: 93.359375
# Train		Epoch: 7 	Batch 10/23 (43%) 	Batch Loss: 0.391115 	Batch Accuracy: 93.339844
# Train		Epoch: 7 	Batch 11/23 (48%) 	Batch Loss: 0.388661 	Batch Accuracy: 93.359375
# Train		Epoch: 7 	Batch 12/23 (52%) 	Batch Loss: 0.372428 	Batch Accuracy: 93.457031
# Train		Epoch: 7 	Batch 13/23 (57%) 	Batch Loss: 0.369861 	Batch Accuracy: 93.539663
# Train		Epoch: 7 	Batch 14/23 (61%) 	Batch Loss: 0.357874 	Batch Accuracy: 93.554688
# Train		Epoch: 7 	Batch 15/23 (65%) 	Batch Loss: 0.370126 	Batch Accuracy: 93.580729
# Train		Epoch: 7 	Batch 16/23 (70%) 	Batch Loss: 0.365307 	Batch Accuracy: 93.505859
# Train		Epoch: 7 	Batch 17/23 (74%) 	Batch Loss: 0.341726 	Batch Accuracy: 93.600643
# Train		Epoch: 7 	Batch 18/23 (78%) 	Batch Loss: 0.347229 	Batch Accuracy: 93.619792
# Train		Epoch: 7 	Batch 19/23 (83%) 	Batch Loss: 0.351072 	Batch Accuracy: 93.636924
# Train		Epoch: 7 	Batch 20/23 (87%) 	Batch Loss: 0.340390 	Batch Accuracy: 93.671875
# Train		Epoch: 7 	Batch 21/23 (91%) 	Batch Loss: 0.340062 	Batch Accuracy: 93.666295
# Train		Epoch: 7 	Batch 22/23 (96%) 	Batch Loss: 0.308955 	Batch Accuracy: 93.803267
# Train		Epoch: 7 	Batch 23/23 (100%) 	Batch Loss: 0.322707 	Batch Accuracy: 93.817935
# 95.67594433399603
# Train		Epoch: 8 	Batch 1/23 (4%) 	Batch Loss: 0.318934 	Batch Accuracy: 94.531250
# Train		Epoch: 8 	Batch 2/23 (9%) 	Batch Loss: 0.308755 	Batch Accuracy: 95.019531
# Train		Epoch: 8 	Batch 3/23 (13%) 	Batch Loss: 0.312006 	Batch Accuracy: 95.052083
# Train		Epoch: 8 	Batch 4/23 (17%) 	Batch Loss: 0.298184 	Batch Accuracy: 95.507812
# Train		Epoch: 8 	Batch 5/23 (22%) 	Batch Loss: 0.294844 	Batch Accuracy: 95.507812
# Train		Epoch: 8 	Batch 6/23 (26%) 	Batch Loss: 0.301060 	Batch Accuracy: 95.475260
# Train		Epoch: 8 	Batch 7/23 (30%) 	Batch Loss: 0.285398 	Batch Accuracy: 95.507812
# Train		Epoch: 8 	Batch 8/23 (35%) 	Batch Loss: 0.278941 	Batch Accuracy: 95.581055
# Train		Epoch: 8 	Batch 9/23 (39%) 	Batch Loss: 0.281952 	Batch Accuracy: 95.659722
# Train		Epoch: 8 	Batch 10/23 (43%) 	Batch Loss: 0.289674 	Batch Accuracy: 95.507812
# Train		Epoch: 8 	Batch 11/23 (48%) 	Batch Loss: 0.262554 	Batch Accuracy: 95.614347
# Train		Epoch: 8 	Batch 12/23 (52%) 	Batch Loss: 0.272684 	Batch Accuracy: 95.556641
# Train		Epoch: 8 	Batch 13/23 (57%) 	Batch Loss: 0.280183 	Batch Accuracy: 95.477764
# Train		Epoch: 8 	Batch 14/23 (61%) 	Batch Loss: 0.290294 	Batch Accuracy: 95.340402
# Train		Epoch: 8 	Batch 15/23 (65%) 	Batch Loss: 0.246185 	Batch Accuracy: 95.442708
# Train		Epoch: 8 	Batch 16/23 (70%) 	Batch Loss: 0.262719 	Batch Accuracy: 95.446777
# Train		Epoch: 8 	Batch 17/23 (74%) 	Batch Loss: 0.240331 	Batch Accuracy: 95.530790
# Train		Epoch: 8 	Batch 18/23 (78%) 	Batch Loss: 0.258521 	Batch Accuracy: 95.486111
# Train		Epoch: 8 	Batch 19/23 (83%) 	Batch Loss: 0.252329 	Batch Accuracy: 95.456414
# Train		Epoch: 8 	Batch 20/23 (87%) 	Batch Loss: 0.252640 	Batch Accuracy: 95.400391
# Train		Epoch: 8 	Batch 21/23 (91%) 	Batch Loss: 0.246422 	Batch Accuracy: 95.386905
# Train		Epoch: 8 	Batch 22/23 (96%) 	Batch Loss: 0.245351 	Batch Accuracy: 95.356889
# Train		Epoch: 8 	Batch 23/23 (100%) 	Batch Loss: 0.230059 	Batch Accuracy: 95.405910
# 96.3220675944334
# Train		Epoch: 9 	Batch 1/23 (4%) 	Batch Loss: 0.247620 	Batch Accuracy: 95.312500
# Train		Epoch: 9 	Batch 2/23 (9%) 	Batch Loss: 0.228914 	Batch Accuracy: 95.703125
# Train		Epoch: 9 	Batch 3/23 (13%) 	Batch Loss: 0.223509 	Batch Accuracy: 95.768229
# Train		Epoch: 9 	Batch 4/23 (17%) 	Batch Loss: 0.219028 	Batch Accuracy: 95.947266
# Train		Epoch: 9 	Batch 5/23 (22%) 	Batch Loss: 0.221369 	Batch Accuracy: 95.937500
# Train		Epoch: 9 	Batch 6/23 (26%) 	Batch Loss: 0.239375 	Batch Accuracy: 95.768229
# Train		Epoch: 9 	Batch 7/23 (30%) 	Batch Loss: 0.215831 	Batch Accuracy: 95.814732
# Train		Epoch: 9 	Batch 8/23 (35%) 	Batch Loss: 0.210362 	Batch Accuracy: 95.947266
# Train		Epoch: 9 	Batch 9/23 (39%) 	Batch Loss: 0.215588 	Batch Accuracy: 95.941840
# Train		Epoch: 9 	Batch 10/23 (43%) 	Batch Loss: 0.218144 	Batch Accuracy: 95.898438
# Train		Epoch: 9 	Batch 11/23 (48%) 	Batch Loss: 0.226330 	Batch Accuracy: 95.827415
# Train		Epoch: 9 	Batch 12/23 (52%) 	Batch Loss: 0.194084 	Batch Accuracy: 95.930990
# Train		Epoch: 9 	Batch 13/23 (57%) 	Batch Loss: 0.193968 	Batch Accuracy: 95.988582
# Train		Epoch: 9 	Batch 14/23 (61%) 	Batch Loss: 0.195429 	Batch Accuracy: 96.065848
# Train		Epoch: 9 	Batch 15/23 (65%) 	Batch Loss: 0.201873 	Batch Accuracy: 96.054688
# Train		Epoch: 9 	Batch 16/23 (70%) 	Batch Loss: 0.200751 	Batch Accuracy: 96.057129
# Train		Epoch: 9 	Batch 17/23 (74%) 	Batch Loss: 0.184439 	Batch Accuracy: 96.139706
# Train		Epoch: 9 	Batch 18/23 (78%) 	Batch Loss: 0.208224 	Batch Accuracy: 96.082899
# Train		Epoch: 9 	Batch 19/23 (83%) 	Batch Loss: 0.189387 	Batch Accuracy: 96.114309
# Train		Epoch: 9 	Batch 20/23 (87%) 	Batch Loss: 0.199170 	Batch Accuracy: 96.093750
# Train		Epoch: 9 	Batch 21/23 (91%) 	Batch Loss: 0.195499 	Batch Accuracy: 96.103051
# Train		Epoch: 9 	Batch 22/23 (96%) 	Batch Loss: 0.184093 	Batch Accuracy: 96.102628
# Train		Epoch: 9 	Batch 23/23 (100%) 	Batch Loss: 0.191232 	Batch Accuracy: 96.119226
# 97.16699801192843
# Train		Epoch: 10 	Batch 1/23 (4%) 	Batch Loss: 0.189253 	Batch Accuracy: 96.289062
# Train		Epoch: 10 	Batch 2/23 (9%) 	Batch Loss: 0.196279 	Batch Accuracy: 95.898438
# Train		Epoch: 10 	Batch 3/23 (13%) 	Batch Loss: 0.178004 	Batch Accuracy: 96.158854
# Train		Epoch: 10 	Batch 4/23 (17%) 	Batch Loss: 0.193661 	Batch Accuracy: 95.849609
# Train		Epoch: 10 	Batch 5/23 (22%) 	Batch Loss: 0.187753 	Batch Accuracy: 95.976562
# Train		Epoch: 10 	Batch 6/23 (26%) 	Batch Loss: 0.171006 	Batch Accuracy: 96.126302
# Train		Epoch: 10 	Batch 7/23 (30%) 	Batch Loss: 0.170232 	Batch Accuracy: 96.261161
# Train		Epoch: 10 	Batch 8/23 (35%) 	Batch Loss: 0.174723 	Batch Accuracy: 96.313477
# Train		Epoch: 10 	Batch 9/23 (39%) 	Batch Loss: 0.196810 	Batch Accuracy: 96.180556
# Train		Epoch: 10 	Batch 10/23 (43%) 	Batch Loss: 0.193643 	Batch Accuracy: 96.093750
# Train		Epoch: 10 	Batch 11/23 (48%) 	Batch Loss: 0.167960 	Batch Accuracy: 96.129261
# Train		Epoch: 10 	Batch 12/23 (52%) 	Batch Loss: 0.195480 	Batch Accuracy: 96.061198
# Train		Epoch: 10 	Batch 13/23 (57%) 	Batch Loss: 0.145458 	Batch Accuracy: 96.198918
# Train		Epoch: 10 	Batch 14/23 (61%) 	Batch Loss: 0.153647 	Batch Accuracy: 96.303013
# Train		Epoch: 10 	Batch 15/23 (65%) 	Batch Loss: 0.170940 	Batch Accuracy: 96.289062
# Train		Epoch: 10 	Batch 16/23 (70%) 	Batch Loss: 0.184461 	Batch Accuracy: 96.276855
# Train		Epoch: 10 	Batch 17/23 (74%) 	Batch Loss: 0.171224 	Batch Accuracy: 96.277574
# Train		Epoch: 10 	Batch 18/23 (78%) 	Batch Loss: 0.150002 	Batch Accuracy: 96.343316
# Train		Epoch: 10 	Batch 19/23 (83%) 	Batch Loss: 0.138490 	Batch Accuracy: 96.453536
# Train		Epoch: 10 	Batch 20/23 (87%) 	Batch Loss: 0.167222 	Batch Accuracy: 96.474609
# Train		Epoch: 10 	Batch 21/23 (91%) 	Batch Loss: 0.142958 	Batch Accuracy: 96.502976
# Train		Epoch: 10 	Batch 22/23 (96%) 	Batch Loss: 0.156590 	Batch Accuracy: 96.511009
# Train		Epoch: 10 	Batch 23/23 (100%) 	Batch Loss: 0.165181 	Batch Accuracy: 96.484375
# 97.21669980119285
